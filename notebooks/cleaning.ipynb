# %%
import pandas as pd

# %%
raw_collisions = pd.read_csv('../data/raw/nyc_collisions_sample.csv')
raw_collisions.head()
# Out:
#        CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0      03/08/2022      23:00        NaN       NaN        NaN        NaN
# 1      07/24/2021      18:51  MANHATTAN   10026.0  40.802480 -73.954850
# 2      01/22/2023      16:16   BROOKLYN   11221.0  40.689420 -73.921970
# 3      07/24/2021      21:20        NaN       NaN  40.751526 -73.859184
# 4      03/31/2022       9:00     QUEENS   11377.0  40.756298 -73.898930
# ...           ...        ...        ...       ...        ...        ...
# 27159  02/12/2020      23:15        NaN       NaN  40.665794 -73.746400
# 27160  02/28/2025      18:25      BRONX   10461.0  40.850304 -73.851364
# 27161  12/27/2024      19:49   BROOKLYN   11205.0  40.689445 -73.955124
# 27162  10/23/2024      11:12        NaN       NaN  40.744892 -73.770220
# 27163  08/26/2024       7:50   BROOKLYN   11207.0  40.683510 -73.895170
#
#                       LOCATION                    ON STREET NAME  \
# 0                          NaN                  LINDEN BOULEVARD
# 1        (40.80248, -73.95485)                               NaN
# 2        (40.68942, -73.92197)                               NaN
# 3      (40.751526, -73.859184)                        108 STREET
# 4       (40.756298, -73.89893)                         32 AVENUE
# ...                        ...                               ...
# 27159    (40.665794, -73.7464)  BELT PARKWAY
# 27160  (40.850304, -73.851364)                   MORRIS PARK AVE
# 27161  (40.689445, -73.955124)                       BEDFORD AVE
# 27162   (40.744892, -73.77022)            LONG ISLAND EXPRESSWAY
# 27163    (40.68351, -73.89517)                               NaN
#
#           CROSS STREET NAME            OFF STREET NAME  ...  \
# 0      SOUTH CONDUIT AVENUE                        NaN  ...
# 1                       NaN  234       WEST 114 STREET  ...
# 2                       NaN         1366      BROADWAY  ...
# 3                       NaN                        NaN  ...
# 4                 68 STREET                        NaN  ...
# ...                     ...                        ...  ...
# 27159                   NaN                        NaN  ...
# 27160     WILLIAMSBRIDGE RD                        NaN  ...
# 27161         LAFAYETTE AVE                        NaN  ...
# 27162                   NaN                        NaN  ...
# 27163                   NaN    3         VERMONT COURT  ...
#
#        CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                        Unspecified                            NaN
# 1                        Unspecified                    Unspecified
# 2                        Unspecified                    Unspecified
# 3                        Unspecified                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 27159                            NaN                            NaN
# 27160                    Unspecified                            NaN
# 27161                    Unspecified                            NaN
# 27162                    Unspecified                            NaN
# 27163                            NaN                            NaN
#
#        CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ...                              ...                            ...
# 27159                            NaN                            NaN
# 27160                            NaN                            NaN
# 27161                            NaN                            NaN
# 27162                            NaN                            NaN
# 27163                            NaN                            NaN
#
#        COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 0           4508554  Station Wagon/Sport Utility Vehicle
# 1           4444677  Station Wagon/Sport Utility Vehicle
# 2           4601423                                Sedan
# 3           4441397                               E-Bike
# 4           4514997  Station Wagon/Sport Utility Vehicle
# ...             ...                                  ...
# 27159       4287932  Station Wagon/Sport Utility Vehicle
# 27160       4796385                           Motorcycle
# 27161       4781882                                Sedan
# 27162       4765800                 Tractor Truck Diesel
# 27163       4752850  Station Wagon/Sport Utility Vehicle
#
#                        VEHICLE TYPE CODE 2  \
# 0      Station Wagon/Sport Utility Vehicle
# 1                                    Sedan
# 2      Station Wagon/Sport Utility Vehicle
# 3      Station Wagon/Sport Utility Vehicle
# 4                                      NaN
# ...                                    ...
# 27159                                  NaN
# 27160                             MOBILITY
# 27161                                Sedan
# 27162                 Tractor Truck Diesel
# 27163                                  NaN
#
#                        VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                                      NaN                 NaN
# 1                                    Sedan                 NaN
# 2      Station Wagon/Sport Utility Vehicle                 NaN
# 3                                      NaN                 NaN
# 4                                      NaN                 NaN
# ...                                    ...                 ...
# 27159                                  NaN                 NaN
# 27160                                  NaN                 NaN
# 27161                                  NaN                 NaN
# 27162                                  NaN                 NaN
# 27163                                  NaN                 NaN
#
#       VEHICLE TYPE CODE 5
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 27159                 NaN
# 27160                 NaN
# 27161                 NaN
# 27162                 NaN
# 27163                 NaN
#
# [27164 rows x 29 columns]

# %% [markdown]
# So let's develop a plan based on what we see above ^  :
#
# 1. normalize column names converting stuff to snake_case and lower case
# 2. drop location, it's unneeded (latitude,longitude)
# 3. combine date and time
# 4. cast zipcode to integer
# 5.
